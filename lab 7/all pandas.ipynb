# %%
import pandas as pd

df = pd.read_csv('heart.csv')
df.info()


df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %%
df.tail(3)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
len(df)
# Out:
# 1025

# %%
df.set_index('Payment ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29864\656334368.py in ?()
# ----> 1 df.set_index('Payment ID')
#
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Payment ID'] are in the columns"

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      0   52    1   0       125   212    0        1      168      0      1.0
# 1      1   53    1   0       140   203    1        0      155      1      3.1
# 2      2   70    1   0       145   174    0        1      125      1      2.6
# 3      3   61    1   0       148   203    0        1      161      0      0.0
# 4      4   62    0   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
df.loc('62')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: '62'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29864\3974470224.py in ?()
# ----> 1 df.loc('62')
#
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...

# %%
df.loc('5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: '5'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29864\867197599.py in ?()
# ----> 1 df.loc('5')
#
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...

# %%
df.loc(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29864\3356811634.py in ?()
# ----> 1 df.loc(5)
#
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...

# %%
df.loc['62']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.loc['62']
#
# File c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# ...

# %%
df.loc[5]
# Out:
# index         5.0
# age          58.0
# sex           0.0
# cp            0.0
# trestbps    100.0
# chol        248.0
# fbs           0.0
# restecg       0.0
# thalach     122.0
# exang         0.0
# oldpeak       1.0
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 5, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     1025 non-null   int64
#  1   age       1025 non-null   int64
#  2   sex       1025 non-null   int64
#  3   cp        1025 non-null   int64
#  4   trestbps  1025 non-null   int64
#  5   chol      1025 non-null   int64
#  6   fbs       1025 non-null   int64
#  7   restecg   1025 non-null   int64
#  8   thalach   1025 non-null   int64
#  9   exang     1025 non-null   int64
#  10  oldpeak   1025 non-null   float64
#  11  slope     1025 non-null   int64
#  12  ca        1025 non-null   int64
#  13  thal      1025 non-null   int64
#  14  target    1025 non-null   int64
# dtypes: float64(1), int64(14)
# memory usage: 120.2 KB

# %%
df.describe()
# Out:
#              index          age          sex           cp     trestbps  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    512.000000    54.434146     0.695610     0.942439   131.611707
# std     296.036315     9.072290     0.460373     1.029641    17.516718
# min       0.000000    29.000000     0.000000     0.000000    94.000000
# 25%     256.000000    48.000000     0.000000     0.000000   120.000000
# 50%     512.000000    56.000000     1.000000     1.000000   130.000000
# 75%     768.000000    61.000000     1.000000     2.000000   140.000000
# max    1024.000000    77.000000     1.000000     3.000000   200.000000
#
#              chol          fbs      restecg      thalach        exang  \
# count  1025.00000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    246.00000     0.149268     0.529756   149.114146     0.336585
# std      51.59251     0.356527     0.527878    23.005724     0.472772
# ...

# %%
df.groupby('age')

# %%
df.groupby('age').mean()
# Out:
#           index       sex        cp    trestbps        chol       fbs  \
# age
# 29   227.500000  1.000000  1.000000  130.000000  204.000000  0.000000
# 34   287.000000  0.500000  2.000000  118.000000  196.000000  0.000000
# 35   568.533333  0.733333  0.266667  126.533333  209.200000  0.000000
# 37   349.666667  0.500000  2.000000  125.000000  232.500000  0.000000
# 38   474.500000  1.000000  2.333333  132.000000  193.666667  0.000000
# 39   546.857143  0.500000  1.428571  123.285714  236.857143  0.000000
# 40   448.181818  1.000000  0.818182  133.454545  196.090909  0.000000
# 41   474.906250  0.625000  1.187500  119.531250  218.156250  0.000000
# 42   565.115385  0.769231  1.230769  127.461538  246.807692  0.115385
# 43   501.692308  0.730769  0.461538  126.346154  256.923077  0.269231
# 44   500.416667  0.833333  1.166667  120.666667  220.000000  0.000000
# 45   512.560000  0.600000  0.760000  122.680000  246.840000  0.000000
# ...

# %%
df.groupby('age', 'sex').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29864\929933180.py in ?()
# ----> 1 df.groupby('age', 'sex').mean()
#
# c:\Users\azama\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9156         observed: bool | lib.NoDefault = lib.no_default,
# ...

# %%
df.groupby(['sex','age']).mean()
# Out:
#               index        cp    trestbps        chol       fbs   restecg  \
# sex age
# 0   34   268.666667  1.000000  118.000000  210.000000  0.000000  1.000000
#     35   611.000000  0.000000  138.000000  183.000000  0.000000  1.000000
#     37   160.666667  2.000000  120.000000  215.000000  0.000000  1.000000
#     39   369.714286  2.000000  119.142857  211.000000  0.000000  1.000000
#     41   480.583333  1.250000  118.250000  244.000000  0.000000  0.500000
# ...             ...       ...         ...         ...       ...       ...
# 1   67   483.227273  0.363636  131.045455  250.681818  0.136364  0.318182
#     68   585.777778  1.333333  147.333333  248.000000  0.666667  0.666667
#     69   468.666667  2.500000  150.000000  244.000000  0.500000  0.000000
#     70   529.142857  0.642857  146.285714  251.857143  0.000000  0.500000
#     77   236.333333  0.000000  125.000000  304.000000  0.000000  0.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     1025 non-null   int64
#  1   age       1025 non-null   int64
#  2   sex       1025 non-null   int64
#  3   cp        1025 non-null   int64
#  4   trestbps  1025 non-null   int64
#  5   chol      1025 non-null   int64
#  6   fbs       1025 non-null   int64
#  7   restecg   1025 non-null   int64
#  8   thalach   1025 non-null   int64
#  9   exang     1025 non-null   int64
#  10  oldpeak   1025 non-null   float64
#  11  slope     1025 non-null   int64
#  12  ca        1025 non-null   int64
#  13  thal      1025 non-null   int64
#  14  target    1025 non-null   int64
# dtypes: float64(1), int64(14)
# memory usage: 120.2 KB

# %%
def eligible(age):
    return (True if age > 50 else False)

df['eligibility'] = df['age'].apply(eligible)

df.head()
# Out:
#    index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      0   52    1   0       125   212    0        1      168      0      1.0
# 1      1   53    1   0       140   203    1        0      155      1      3.1
# 2      2   70    1   0       145   174    0        1      125      1      2.6
# 3      3   61    1   0       148   203    0        1      161      0      0.0
# 4      4   62    0   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target  eligibility
# 0      2   2     3       0         True
# 1      0   0     3       0         True
# 2      0   0     3       0         True
# 3      2   1     3       0         True
# 4      1   3     2       0         True
